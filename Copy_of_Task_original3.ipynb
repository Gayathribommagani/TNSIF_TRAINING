# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayathribommagani/TNSIF_TRAINING/blob/main/Copy_of_Task_original3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Global YouTube Statistics.csv",encoding='latin-1')
print(df.head())

top_subscribers = df[['Youtuber', 'subscribers']].sort_values(
    by='subscribers', ascending=False).head(10)
print("\nTop 10 Channels by Subscribers:")
print(top_subscribers)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(top_subscribers['Youtuber'], top_subscribers['subscribers'])
plt.xticks(rotation=90)
plt.xlabel("YouTube Channel")
plt.ylabel("Subscribers")
plt.title("Top 10 YouTube Channels by Subscribers")
plt.show()
top_views = df[['Youtuber', 'video views']].sort_values(
    by='video views', ascending=False).head(10)

# %%
print("\nTop 10 Channels by Video Views:")
print(top_views)

plt.figure(figsize=(10,5))
plt.bar(top_views['Youtuber'], top_views['video views'])
plt.xticks(rotation=90)
plt.xlabel("YouTube Channel")
plt.ylabel("Video Views")
plt.title("Top 10 YouTube Channels by Video Views")
plt.show()
# Out:
# Top 10 Channels by Video Views:
#                       Youtuber   video views
# 0                     T-Series  2.280000e+11
# 3   Cocomelon - Nursery Rhymes  1.640000e+11
# 4                    SET India  1.480000e+11
# 15                    Sony SAB  1.010000e+11
# 6          ýýý Kids Diana Show  9.324704e+10
# 8                  Like Nastya  9.047906e+10
# 11                         WWE  7.742847e+10
# 9                Vlad and Niki  7.718017e+10
# 21                      Zee TV  7.313905e+10
# 26                   Colors TV  6.151091e+10

# %%
print("\nTop 10 Channels by Video Views:")
print(top_views)

plt.figure(figsize=(10,5))
plt.bar(top_views['Youtuber'], top_views['video views'])
plt.xticks(rotation=90)
plt.xlabel("YouTube Channel")
plt.ylabel("Video Views")
plt.title("Top 10 YouTube Channels by Video Views")
plt.show()
# Out:
# Top 10 Channels by Video Views:
#                       Youtuber   video views
# 0                     T-Series  2.280000e+11
# 3   Cocomelon - Nursery Rhymes  1.640000e+11
# 4                    SET India  1.480000e+11
# 15                    Sony SAB  1.010000e+11
# 6          ýýý Kids Diana Show  9.324704e+10
# 8                  Like Nastya  9.047906e+10
# 11                         WWE  7.742847e+10
# 9                Vlad and Niki  7.718017e+10
# 21                      Zee TV  7.313905e+10
# 26                   Colors TV  6.151091e+10
