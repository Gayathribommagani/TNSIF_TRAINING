# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayathribommagani/TNSIF_TRAINING/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FUNCTIONS**

# %%
# Basic Function Program
def function_name():
  #function body
  print("HELLO WORLD!")
function_name()
# Out:
# HELLO WORLD!

# %%
# Program on Function Without Parameters and Without Return Value
def display():
  print("Learning Python")
display()
# Out:
# Learning Python

# %%
# Program on Function With Parameters
def greet(name):
  print("Hii",name)
greet("Namratha")
greet("Karthik")
# Out:
# Hii Namratha
# Hii Karthik

# %%
# Program on Function With Return Value
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30

# %%
# Program on Function With Parameters and Return Value
def square(num):
  return num*num
result=square(5)
print(result)
# Out:
# 25
